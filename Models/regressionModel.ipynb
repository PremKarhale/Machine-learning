# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv(r"c:\Users\Admin\Documents\DataSets\insurance.csv")

# %%
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
plt.hist(df['age'])
# Out:
# (array([222., 140., 109., 128., 102., 137., 144., 114., 128., 114.]),
#  array([18. , 22.6, 27.2, 31.8, 36.4, 41. , 45.6, 50.2, 54.8, 59.4, 64. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.pairplot(df, vars=['age', 'bmi', 'charges'], hue='smoker')

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
df['sex']=df['sex'].replace({"male":1,"female":0})
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18540\3884093727.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['sex']=df['sex'].replace({"male":1,"female":0})

# %%
df
# Out:
#       age  sex     bmi  children smoker     region      charges
# 0      19    0  27.900         0    yes  southwest  16884.92400
# 1      18    1  33.770         1     no  southeast   1725.55230
# 2      28    1  33.000         3     no  southeast   4449.46200
# 3      33    1  22.705         0     no  northwest  21984.47061
# 4      32    1  28.880         0     no  northwest   3866.85520
# ...   ...  ...     ...       ...    ...        ...          ...
# 1333   50    1  30.970         3     no  northwest  10600.54830
# 1334   18    0  31.920         0     no  northeast   2205.98080
# 1335   18    0  36.850         0     no  southeast   1629.83350
# 1336   21    0  25.800         0     no  southwest   2007.94500
# 1337   61    0  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df['region'].value_counts()
# Out:
# region
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: count, dtype: int64

# %%
df['region']= df['region'].replace({"southeast":0,"southwest":1,"northwest":2,"northeast":3})
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18540\2204732866.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['region']= df['region'].replace({"southeast":0,"southwest":1,"northwest":2,"northeast":3})

# %%
df
# Out:
#       age  sex     bmi  children smoker  region      charges
# 0      19    0  27.900         0    yes       1  16884.92400
# 1      18    1  33.770         1     no       0   1725.55230
# 2      28    1  33.000         3     no       0   4449.46200
# 3      33    1  22.705         0     no       2  21984.47061
# 4      32    1  28.880         0     no       2   3866.85520
# ...   ...  ...     ...       ...    ...     ...          ...
# 1333   50    1  30.970         3     no       2  10600.54830
# 1334   18    0  31.920         0     no       3   2205.98080
# 1335   18    0  36.850         0     no       0   1629.83350
# 1336   21    0  25.800         0     no       1   2007.94500
# 1337   61    0  29.070         0    yes       2  29141.36030
#
# [1338 rows x 7 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
le.fit(df['smoker'])
# Out:
# LabelEncoder()

# %%
df['smoker']=le.transform(df['smoker'])

# %%
df['smoker']
# Out:
# 0       1
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1333    0
# 1334    0
# 1335    0
# 1336    0
# 1337    1
# Name: smoker, Length: 1338, dtype: int64

# %%
df
# Out:
#       age  sex     bmi  children  smoker  region      charges
# 0      19    0  27.900         0       1       1  16884.92400
# 1      18    1  33.770         1       0       0   1725.55230
# 2      28    1  33.000         3       0       0   4449.46200
# 3      33    1  22.705         0       0       2  21984.47061
# 4      32    1  28.880         0       0       2   3866.85520
# ...   ...  ...     ...       ...     ...     ...          ...
# 1333   50    1  30.970         3       0       2  10600.54830
# 1334   18    0  31.920         0       0       3   2205.98080
# 1335   18    0  36.850         0       0       0   1629.83350
# 1336   21    0  25.800         0       0       1   2007.94500
# 1337   61    0  29.070         0       1       2  29141.36030
#
# [1338 rows x 7 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train , X_test ,Y_train,Y_test = train_test_split(df.iloc[:,0:6] , df.iloc[:,-1] , test_size=0.2 , random_state=42)

# %%
X_train.shape
# Out:
# (1070, 6)

# %%
X_test.shape
# Out:
# (268, 6)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X_train , Y_train)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([ 2.56600616e+02, -1.85353207e+01,  3.39184210e+02,  4.23674513e+02,
#         2.36702619e+04,  2.41362103e+02])

# %%
model.intercept_
# Out:
# np.float64(-12800.773996456655)

# %%
y_pred = model.predict(X_test)

# %%
y_pred=pd.DataFrame(y_pred ,columns=['charges'])

# %%
Y_test
# Out:
# 764      9095.06825
# 887      5272.17580
# 890     29330.98315
# 1293     9301.89355
# 259     33750.29180
#            ...
# 109     47055.53210
# 575     12222.89830
# 535      6067.12675
# 543     63770.42801
# 846      9872.70100
# Name: charges, Length: 268, dtype: float64

# %%
y_pred
# Out:
#           charges
# 0     8856.651536
# 1     7101.882358
# 2    36893.618988
# 3     9470.364241
# 4    27035.848445
# ..            ...
# 263  38918.765285
# 264  11780.420912
# 265   7584.912388
# 266  40806.644525
# 267  12550.994005
#
# [268 rows x 1 columns]

# %%
from sklearn.metrics import r2_score ,mean_squared_error ,mean_absolute_error

# %%
R2=r2_score(Y_test , y_pred)

# %%
R2
# Out:
# 0.7839279776463969
