# %%
import pandas as pd

# %%
df=pd.read_csv(r"c:\Users\Admin\Downloads\Titanic-Dataset.csv",encoding='latin')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head(7)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# ...

# %% [markdown]
# to get the 5 random data from the dataset

# %%
df.sample(5) # it gives 5 sample from the data set of different catagories
# Out:
#      PassengerId  Survived  Pclass                              Name     Sex  \
# 845          846         0       3               Abbing, Mr. Anthony    male
# 399          400         1       2  Trout, Mrs. William H (Jessie L)  female
# 122          123         0       2              Nasser, Mr. Nicholas    male
# 212          213         0       3            Perkin, Mr. John Henry    male
# 4              5         0       3          Allen, Mr. William Henry    male
#
#       Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# 845  42.0      0      0  C.A. 5547   7.5500   NaN        S
# 399  28.0      0      0     240929  12.6500   NaN        S
# 122  32.5      1      0     237736  30.0708   NaN        C
# 212  22.0      0      0  A/5 21174   7.2500   NaN        S
# 4    35.0      0      0     373450   8.0500   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe() # to draw the insights from the numerical col
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# To check for any duplicate values

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # to find the correclation between the data

# %%
df=df.drop(columns=['Name','Ticket','Cabin']) # drop the unwanted cols

# %%
df
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare  \
# 0              1         0       3    male  22.0      1      0   7.2500
# 1              2         1       1  female  38.0      1      0  71.2833
# 2              3         1       3  female  26.0      0      0   7.9250
# 3              4         1       1  female  35.0      1      0  53.1000
# 4              5         0       3    male  35.0      0      0   8.0500
# ..           ...       ...     ...     ...   ...    ...    ...      ...
# 886          887         0       2    male  27.0      0      0  13.0000
# 887          888         1       1  female  19.0      0      0  30.0000
# 888          889         0       3  female   NaN      1      2  23.4500
# 889          890         1       1    male  26.0      0      0  30.0000
# 890          891         0       3    male  32.0      0      0   7.7500
#
#     Embarked
# 0          S
# 1          C
# 2          S
# 3          S
# 4          S
# ..       ...
# ...

# %%
df['Sex']=df['Sex'].map({'male':0,'female':1}) # encode the catagorical col 
df['Embarked'] = df['Embarked'].map({'S':0,'C':1,'Q':2})

# %%
df
# Out:
#      PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0              1         0       3    0  22.0      1      0   7.2500       0.0
# 1              2         1       1    1  38.0      1      0  71.2833       1.0
# 2              3         1       3    1  26.0      0      0   7.9250       0.0
# 3              4         1       1    1  35.0      1      0  53.1000       0.0
# 4              5         0       3    0  35.0      0      0   8.0500       0.0
# ..           ...       ...     ...  ...   ...    ...    ...      ...       ...
# 886          887         0       2    0  27.0      0      0  13.0000       0.0
# 887          888         1       1    1  19.0      0      0  30.0000       0.0
# 888          889         0       3    1   NaN      1      2  23.4500       0.0
# 889          890         1       1    0  26.0      0      0  30.0000       1.0
# 890          891         0       3    0  32.0      0      0   7.7500       2.0
#
# [891 rows x 9 columns]

# %%
df.corr()['Survived']   # varies between -1 to 1      # more the +ve relation more it depends on the target var
# Out:
# PassengerId   -0.005007
# Survived       1.000000
# Pclass        -0.338481
# Sex            0.543351
# Age           -0.077221
# SibSp         -0.035322
# Parch          0.081629
# Fare           0.257307
# Embarked       0.108669
# Name: Survived, dtype: float64
